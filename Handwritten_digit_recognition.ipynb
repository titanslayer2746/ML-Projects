# %% [markdown]
# <a href="https://colab.research.google.com/github/titanslayer2746/ML-Projects/blob/main/Handwritten_digit_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow as tf

# %%
#Loading Dataset
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
#Noramlizing Values of training and testing inputs
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2598 - accuracy: 0.9251
# Epoch 2/3
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1062 - accuracy: 0.9668
# Epoch 3/3
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0723 - accuracy: 0.9771

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(loss)
print(accuracy)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0932 - accuracy: 0.9683
# 0.09323406964540482
# 0.9682999849319458

# %%
for i in range(10):
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.show()
    print(model.predict(x_test[i].reshape(1,28,28)))
    print("The number is probably",y_test[i])
# Out:
# 1/1 [==============================] - 0s 117ms/step
# [[2.6015630e-09 2.3250141e-08 2.5695663e-06 2.8448516e-05 1.3408560e-10
#   1.4822042e-09 2.9622067e-12 9.9996877e-01 2.3302350e-08 1.2722087e-07]]
# The number is probably 7
# 1/1 [==============================] - 0s 27ms/step
# [[1.0493179e-07 5.5877742e-04 9.9921882e-01 2.0449659e-04 1.7080740e-08
#   9.6694123e-07 9.3111803e-06 4.7768530e-08 7.5577595e-06 2.7757024e-10]]
# The number is probably 2
# 1/1 [==============================] - 0s 23ms/step
# [[4.9458021e-07 9.9862337e-01 2.2696913e-05 3.3973723e-05 5.8542111e-05
#   8.4076703e-07 4.2914100e-05 1.4150549e-04 1.0739242e-03 1.7919147e-06]]
# The number is probably 1
# 1/1 [==============================] - 0s 24ms/step
# [[9.9888855e-01 6.1708724e-06 1.2502741e-04 2.1051485e-05 2.0435540e-05
#   6.7098023e-05 1.6645560e-04 5.9099926e-04 2.7350195e-06 1.1148295e-04]]
# The number is probably 0
# 1/1 [==============================] - 0s 23ms/step
# ...
